# %%
import pandas as pd
import re
from datetime import datetime

# %%
events = pd.read_csv("data/Dataset1.csv")
accidents = pd.read_csv("data/Dataset2.csv")

# %% [markdown]
# ### Fixing Columns

# %%
events.rename(str.lower, axis='columns', inplace=True)
accidents.rename(str.lower, axis='columns', inplace=True)
events.columns = events.columns.str.replace("\s", '_', regex=True).str.replace("\W", '', regex=True)
events.rename(columns=lambda x: x[re.search("[a-zA-Z]", x).start():], inplace=True)
accidents.columns = accidents.columns.str.replace("\s", '_', regex=True).str.replace("\W", '', regex=True)
accidents.rename(columns=lambda x: x[re.search("[a-zA-Z]", x).start():], inplace=True)

# %%
# primary occupation code = North American Industry Classification System codes (NAICS)
# National Occupational Classification (NOC)
events = events.rename(columns={'event_date':'date', 'municipality':'city', 'primary_occupation_code':'NAICS'})
accidents = accidents.rename(columns={'accident_date':'date', 'organization_city':'city', 'occupation_code':'NOC'})

# %% [markdown]
# ### Date Field

# %%
events['date'] = pd.to_datetime(events['date'], format="mixed")
events = events[events['date'] < datetime.now()]

# %%
accidents['date'] = pd.to_datetime(accidents['date'], errors='coerce')
accidents = accidents.dropna(subset=['date']).reset_index(drop=True)
accidents = accidents[accidents['date'] < "2024-12-31"]

# %% [markdown]
# ### Cleaning Text Fields

# %%
def fix_text(s:pd.Series)->pd.Series:
    s = s.str.replace("\s", '_', regex=True)
    s = s.str.replace("\W", '', regex=True)
    s.fillna('', inplace=True)
    s = s.astype(str)
    s = s.apply(str.lower)
    return s

# %%
events['city'] = fix_text(events['city'])

# %%
print(list(events['city'].unique()))
# Out:
# ['scarborough', 'north_bay', 'whitby', 'toronto', 'sault_ste_marie', 'timmins', 'hamilton', 'stoney_creek', 'thunder_bay', 'ottawa', 'lively', 'tillsonburg', 'brougham', 'brampton', 'bowmanville', 'burlington', 'north_york', 'london', 'kitchener', 'mississauga', 'oshawa', 'springwater_twp', 'elliot_lake', 'ajax', 'dryden', 'milton', 'georgetown', 'pickering', 'pontypool', '', 'ingersoll', 'lorignal', 'orillia', 'tiverton', 'holland_landing', 'owen_sound', 'hannon', 'ancaster', 'newmarket', 'sudbury', 'stratford', 'huntsville', 'windsor', 'peterborough', 'port_hope', 'st_catharines', 'vaughan', 'balmertown', 'kapuskasing', 'brantford', 'mount_forest', 'richmond_hill', 'woodbridge', 'markham', 'fort_albany', 'picton', 'caledonia', 'kingston', 'chapleau', 'tilbury', 'parkhill', 'collingwood', 'waubaushene', 'campbellville', 'guelph', 'welland', 'fort_erie', 'hawkesbury', 'chaput_hughes', 'marathon', 'barrie', 'stouffville', 'cambridge', 'cochrane', 'bradford', 'nepean', 'fergus', 'innisfil', 'chatham', 'oakville', 'beamsville', 'paris', 'port_loring', 'belleville', 'waterloo', 'wasaga_beach', 'york', 'erin', 'flamborough', 'wawa', 'geraldton', 'copper_cliff', 'kenogami_lake', 'niagara_falls', 'kettleby', 'concord', 'etobicoke', 'thamesford', 'alliston', 'st_thomas', 'markdale', 'tottenham', 'new_liskeard', 'bath', 'elk_lake', 'sturgeon_falls', 'watford', 'onaping', 'renfrew', 'garson', 'grand_bend', 'salford', 'kleinburg', 'thorold', 'kanata', 'mckerrow', 'otter_rapids', 'guelph_junction', 'perkinsfield', 'penetanguishene', 'strathroy', 'aurora', 'alliston_new_tecumseth', 'woodstock', 'sioux_lookout', 'rexdale', 'ottawa_south', 'shakespeare', 'trenton', 'greater_sudbury', 'spanish', 'simcoe', 'breslau', 'bracebridge', 'virgil', 'elora', 'nanticoke', 'athens', 'south_river', 'mitchell', 'bolton', 'gogama', 'beeton', 'aylmer', 'smiths_falls', 'fraserville', 'lakeshore', 'port_perry', 'casselman', 'orangeville', 'king_city', 'cayuga', 'dubreuilville', 'campbellcroft', 'kearney', 'tecumseh', 'wiarton', 'manotick', 'blue_mountains', 'white_river', 'bloomingdale', 'bramalea', 'midland', 'wallaceburg', 'acton', 'hawkesville', 'maple', 'wheatley', 'point_au_baril_station_and_islands', 'goderich', 'newton', 'beaverton', 'greely', 'moose_factory', 'gloucester', 'brooklin', 'falconbridge', 'leamington', 'thornhill', 'kincardine', 'lakeside', 'wainfleet', 'east_gwillimbury', 'shelburne', 'moorefield', 'cobourg', 'port_robinson', 'elmira', 'utopia', 'dundas', 'napanee', 'blenheim', 'listowel', 'new_hamburg', 'dunnville', 'paisley', 'courtice', 'cornwall', 'emo', 'queensville', 'winchester', 'orleans', 'nairn_centre', 'midhurst', 'alexandria', 'sarnia', 'niagaraonthelake', 'thessalon', 'dorion', 'melancthon', 'terrace_bay_twp', 'streetsville', 'haliburton', 'terra_cotta', 'lindsay', 'fenwick', 'caledon', 'chelmsford', 'amherstburg', 'pembroke', 'worthington', 'englehart', 'ayton', 'otonabeesouth_monaghan', 'baden', 'kemptville', 'kingsville', 'hepworth', 'grimsby', 'fort_frances', 'almonte', 'delhi', 'ayr', 'creighton_twp', 'windermere', 'east_york', 'thornbury', 'oldcastle', 'hagersville', 'mooretown', 'hanmer', 'ottawa_east', 'walkerton', 'espanola', 'uxbridge', 'rodney', 'azilda', 'nairn_and_hyman', 'petawawa', 'loretto', 'glen_cairn', 'st_marys', 'huron_park', 'madsen', 'waterford', 'essex', 'plymptonwyoming', 'mono', 'verner', 'ear_falls', 'caribou_falls', 'minto', 'lambeth', 'brockville', 'pelham', 'hanover', 'matachewan', 'whitestone', 'norwich', 'toledo', 'everett', 'king', 'mckellar', 'southampton', 'port_severn', 'johnstown_twp', 'port_colborne', 'perth', 'eden', 'ridgeway', 'ailsa_craig', 'mindemoya', 'bancroft', 'smithville', 'sarnia_45', 'kenora', 'sharon', 'holtyre', 'waterdown', 'sapawe', 'chathamkent', 'caledon_village', 'springford', 'porcupine', 'kenora_unorganized_', 'petrolia', 'hagar', 'komoka', 'algonquin_highlands', 'teeswater', 'norwood', 'terrace_bay', 'centre_wellington', 'ripley', 'dundalk', 'cameron', 'lamable', 'ki ...

# %%
accidents['city'] = fix_text(accidents['city'])
accidents['industry_sector_description'] = fix_text(accidents['industry_sector_description'])
print(list(accidents['industry_sector_description'].unique()))
# Out:
# ['transportation', 'industrial', 'manufacturing', 'construction', 'services', 'health_care', 'educationindustrial', 'municipal', 'agriculture', 'food', 'electrical', 'mining', 'chemicalprocess', 'not_assigned']

# %% [markdown]
# #### Occupation Description

# %%
events['occupation_description'] = events['occupation_description'].str.lower()
accidents['occupation_description'] = accidents['occupation_description'].str.lower()

# %% [markdown]
# #### NOC

# %%
accidents['NOC'] = accidents['NOC'].apply(lambda x: pd.NA if re.findall("\D", x) else x)
# accidents = accidents.dropna(subset=['NOC'])
accidents
# Out:
#             date  worker_age occupation_category_code  \
# 0     2023-10-14        58.0                       72
# 1     2023-11-04        29.0                      732
# 2     2023-12-17        30.0                      745
# 3     2023-11-13        64.0                      961
# 4     2023-11-13        74.0                      741
# ...          ...         ...                      ...
# 15445 2022-11-25        51.0                      961
# 15446 2023-07-24        57.0                      761
# 15447 2023-07-05        60.0                      735
# 15448 2022-05-05        42.0                      341
# 15449 2021-10-07        68.0                      315
#
#                          occupation_category_description   NOC  \
# 0            FACILITY OPERATION AND MAINTENANCE MANAGERS   722
# 1                                MOTOR VEHICLE MECHANICS  7322
# 2                LONGSHORE WORKERS AND MATERIAL HANDLERS  7453
# 3      LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9613
# 4                      MOTOR VEHICLE AND TRANSIT DRIVERS  7412
# ...                                                  ...   ...
# 15445  LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9619
# 15446                       TRADES HELPERS AND LABOURERS  7612
# 15447  STATIONARY ENGINEERS & POWER STATION &  SYSTEM...  7353
# 15448  ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH SER...  3414
# 15449            NURSE SUPERVISORS AND REGISTERED NURSES  3153
#
#                                   occupation_description  \
# 0                            facility operation managers
# 1      motor vehicle mechanics, technicians and mecha...
# 2                                      material handlers
# 3                         labourers in metal fabrication
# 4                                          truck drivers
# ...                                                  ...
# 15445  other labourers in processing, manufacturing a...
# 15446          construction trades helpers and labourers
# 15447          power systems and power station operators
# 15448                          nurse aides and orderlies
# 15449                                  registered nurses
#
#        worker_experience_in_years  \
# 0                             0.5
# 1                             0.5
# 2                             0.5
# 3                             0.5
# 4                             0.5
# ...                           ...
# 15445                         0.5
# 15446                         0.5
# 15447                         0.5
# 15448                         0.5
# 15449                         NaN
#
#                    accident_source_category_description1  \
# 0                                                 FLOORS
# 1                                                  TRUCK
# 2             PLANT & INDUSTRIAL POWERED VEHICLE, N.E.C.
# 3                                           PARKING LOTS
# 4                                       OTHER STRUCTURES
# ...                                                  ...
# 15445                                      STAIRS, STEPS
# 15446                                            TRACTOR
# 15447   BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15448  HEALTH CARE PATIENT OR RESIDENT OF HEALTH CARE...
# 15449                                             FLOORS
#
#                            source_category_description2  \
# 0                                               UNKNOWN
# 1                 VEHICLE & MOBILE EQUIP. PARTS, N.E.C.
# 2      BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 3                    WEATHER AND ATMOSPHERIC CONDITIONS
# 4                    WEATHER AND ATMOSPHERIC CONDITIONS
# ...                                                 ...
# 15445  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15446                                           UNKNOWN
# 15447  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15448                                           UNKNOWN
# 15449           HEALTH CARE & ORTHOPEDIC EQUIP., N.E.C.
#
#                            accident_category_description  \
# 0                                     FALL ON SAME LEVEL
# 1              CAUGHT IN OR COMPRESSED BY EQUIP./OBJECTS
# 2                                       STRUCK BY OBJECT
# 3                                     FALL ON SAME LEVEL
# 4                                     FALL ON SAME LEVEL
# ...                                                  ...
# 15445                                FALL TO LOWER LEVEL
# 15446     PEDESTRIAN STRUCK BY VEHICLE, MOBILE EQUIPMENT
# 15447                                  REPETITIVE MOTION
# 15448  ASSAULTS, VIOLENT ACTS AND HARASSMENT BY PERSO...
# 15449                                 FALL ON SAME LEVEL
#
#                               accident_place_description        city  \
# 0                                    PLACE NOT SPECIFIED     markham
# 1                                                  FARM.    winnipeg
# 2      RESIDENTIAL INSTITUTION. (HOSPITALS, ORPHANAGE...   harriston
# 3                       PLACE FOR SPORTS AND RECREATION.     markham
# 4                                      PUBLIC BUILDINGS.   newcastle
# ...                                                  ...         ...
# 15445                                              HOME.     toronto
# 15446                                   INDUSTRIAL SITE.   dunchurch
# 15447                                   INDUSTRIAL SITE.        ajax
# 15448                                PLACE NOT SPECIFIED     toronto
# 15449                   PLACE FOR SPORTS AND RECREATION.  pittsburgh
#
#       organization_province_code industry_sector_description
# 0                             ON              transportation
# 1                             MB                  industrial
# 2                             ON                  industrial
# 3                             ON               manufacturing
# 4                             ON                  industrial
# ...                          ...                         ...
# 15445                         ON                construction
# 15446                         ON                construction
# 15447                         ON               manufacturing
# 15448                         ON                 health_care
# 15449                         PA                    services
#
# [15440 rows x 14 columns]

# %% [markdown]
# ### Age

# %%
accidents = accidents[accidents['worker_age'] <= 100]
accidents['worker_experience_in_years'] = accidents['worker_experience_in_years'].fillna(0)
accidents = accidents[accidents['worker_age'] >= accidents['worker_experience_in_years']]
accidents
# Out:
# /var/folders/wn/wdlhry7x1m75kh1md7t0x5p00000gn/T/ipykernel_14525/555888386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents['worker_experience_in_years'] = accidents['worker_experience_in_years'].fillna(0)
#             date  worker_age occupation_category_code  \
# 0     2023-10-14        58.0                       72
# 1     2023-11-04        29.0                      732
# 2     2023-12-17        30.0                      745
# 3     2023-11-13        64.0                      961
# 4     2023-11-13        74.0                      741
# ...          ...         ...                      ...
# 15445 2022-11-25        51.0                      961
# 15446 2023-07-24        57.0                      761
# 15447 2023-07-05        60.0                      735
# 15448 2022-05-05        42.0                      341
# 15449 2021-10-07        68.0                      315
#
#                          occupation_category_description   NOC  \
# 0            FACILITY OPERATION AND MAINTENANCE MANAGERS   722
# 1                                MOTOR VEHICLE MECHANICS  7322
# 2                LONGSHORE WORKERS AND MATERIAL HANDLERS  7453
# 3      LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9613
# 4                      MOTOR VEHICLE AND TRANSIT DRIVERS  7412
# ...                                                  ...   ...
# 15445  LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9619
# 15446                       TRADES HELPERS AND LABOURERS  7612
# 15447  STATIONARY ENGINEERS & POWER STATION &  SYSTEM...  7353
# 15448  ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH SER...  3414
# 15449            NURSE SUPERVISORS AND REGISTERED NURSES  3153
#
#                                   occupation_description  \
# 0                            facility operation managers
# 1      motor vehicle mechanics, technicians and mecha...
# 2                                      material handlers
# 3                         labourers in metal fabrication
# 4                                          truck drivers
# ...                                                  ...
# 15445  other labourers in processing, manufacturing a...
# 15446          construction trades helpers and labourers
# 15447          power systems and power station operators
# 15448                          nurse aides and orderlies
# 15449                                  registered nurses
#
#        worker_experience_in_years  \
# 0                             0.5
# 1                             0.5
# 2                             0.5
# 3                             0.5
# 4                             0.5
# ...                           ...
# 15445                         0.5
# 15446                         0.5
# 15447                         0.5
# 15448                         0.5
# 15449                         0.0
#
#                    accident_source_category_description1  \
# 0                                                 FLOORS
# 1                                                  TRUCK
# 2             PLANT & INDUSTRIAL POWERED VEHICLE, N.E.C.
# 3                                           PARKING LOTS
# 4                                       OTHER STRUCTURES
# ...                                                  ...
# 15445                                      STAIRS, STEPS
# 15446                                            TRACTOR
# 15447   BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15448  HEALTH CARE PATIENT OR RESIDENT OF HEALTH CARE...
# 15449                                             FLOORS
#
#                            source_category_description2  \
# 0                                               UNKNOWN
# 1                 VEHICLE & MOBILE EQUIP. PARTS, N.E.C.
# 2      BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 3                    WEATHER AND ATMOSPHERIC CONDITIONS
# 4                    WEATHER AND ATMOSPHERIC CONDITIONS
# ...                                                 ...
# 15445  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15446                                           UNKNOWN
# 15447  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15448                                           UNKNOWN
# 15449           HEALTH CARE & ORTHOPEDIC EQUIP., N.E.C.
#
#                            accident_category_description  \
# 0                                     FALL ON SAME LEVEL
# 1              CAUGHT IN OR COMPRESSED BY EQUIP./OBJECTS
# 2                                       STRUCK BY OBJECT
# 3                                     FALL ON SAME LEVEL
# 4                                     FALL ON SAME LEVEL
# ...                                                  ...
# 15445                                FALL TO LOWER LEVEL
# 15446     PEDESTRIAN STRUCK BY VEHICLE, MOBILE EQUIPMENT
# 15447                                  REPETITIVE MOTION
# 15448  ASSAULTS, VIOLENT ACTS AND HARASSMENT BY PERSO...
# 15449                                 FALL ON SAME LEVEL
#
#                               accident_place_description        city  \
# 0                                    PLACE NOT SPECIFIED     markham
# 1                                                  FARM.    winnipeg
# 2      RESIDENTIAL INSTITUTION. (HOSPITALS, ORPHANAGE...   harriston
# 3                       PLACE FOR SPORTS AND RECREATION.     markham
# 4                                      PUBLIC BUILDINGS.   newcastle
# ...                                                  ...         ...
# 15445                                              HOME.     toronto
# 15446                                   INDUSTRIAL SITE.   dunchurch
# 15447                                   INDUSTRIAL SITE.        ajax
# 15448                                PLACE NOT SPECIFIED     toronto
# 15449                   PLACE FOR SPORTS AND RECREATION.  pittsburgh
#
#       organization_province_code industry_sector_description
# 0                             ON              transportation
# 1                             MB                  industrial
# 2                             ON                  industrial
# 3                             ON               manufacturing
# 4                             ON                  industrial
# ...                          ...                         ...
# 15445                         ON                construction
# 15446                         ON                construction
# 15447                         ON               manufacturing
# 15448                         ON                 health_care
# 15449                         PA                    services
#
# [15431 rows x 14 columns]

# %% [markdown]
# ### Saving

# %%
events.to_csv('cleaned_data/events.csv', index=0)
accidents.to_csv('cleaned_data/accidents.csv', index=0)
