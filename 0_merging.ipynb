# %%
import pandas as pd
from thefuzz import process
# from fuzzywuzzy import process

events = pd.read_csv('cleaned_data/events.csv')
accidents = pd.read_csv('cleaned_data/accidents.csv')

events['sector'] = events['occupation_description'] + " " + events['sector_description']

sector_description_1 = events['sector'].dropna().unique()
sector_description_2 = (accidents['occupation_description'] + " " + accidents['industry_sector_description'].str.replace('_', ' ')).dropna().unique()

# fuzzy matching
fuzzy_matches = []
for desc2 in sector_description_2:
    match, score = process.extractOne(desc2, sector_description_1)
    fuzzy_matches.append((desc2, match, score))

fuzzy_match_df = pd.DataFrame(fuzzy_matches, columns=['industry_sector_description', 'matched_sector_description', 'match_score'])

fuzzy_match_df
# Out:
#                             industry_sector_description  \
# 0            facility operation managers transportation
# 1     motor vehicle mechanics, technicians and mecha...
# 2                          material handlers industrial
# 3          labourers in metal fabrication manufacturing
# 4                              truck drivers industrial
# ...                                                 ...
# 1370                 aerospace engineers transportation
# 1371                  other services managers municipal
# 1372  transportation route and crew schedulers elect...
# 1373  waterworks and gas maintenance workers constru...
# 1374                     letter carriers transportation
#
#                              matched_sector_description  match_score
# 0     other transportation equipment manufacturing W...           86
# 1            elementary and secondary schools Education           86
# 2      general warehousing and storage NEC - Industrial           86
# 3     all other miscellaneous fabricated metal produ...           86
# 4      general warehousing and storage NEC - Industrial           86
# ...                                                 ...          ...
# 1370  other transportation equipment manufacturing W...           86
# 1371  residential building construction Apartment & ...           86
# 1372  commercial and institutional building construc...           86
# 1373  commercial and institutional building construc...           86
# 1374  other transportation equipment manufacturing W...           86
#
# [1375 rows x 3 columns]

# %% [markdown]
# #### Dates

# %%
events['date'] = pd.to_datetime(events['date'], format="%Y-%m-%d")
accidents['date'] = pd.to_datetime(accidents['date'], format="%Y-%m-%d")

# %% [markdown]
# ### Replacing industry_sector_description with matched_sector_description in accidents dataset

# %%
accidents['industry_sector_description'] = accidents['occupation_description'] + " " + accidents['industry_sector_description'].str.replace('_', ' ')
accidents = pd.merge(accidents, fuzzy_match_df[['industry_sector_description', 'matched_sector_description']], how='left', on='industry_sector_description')
accidents = accidents.drop(columns=['occupation_description', 'industry_sector_description']).rename(columns={'matched_sector_description':'sector'})
accidents
# Out:
#             date  worker_age occupation_category_code  \
# 0     2023-10-14        58.0                       72
# 1     2023-11-04        29.0                      732
# 2     2023-12-17        30.0                      745
# 3     2023-11-13        64.0                      961
# 4     2023-11-13        74.0                      741
# ...          ...         ...                      ...
# 15426 2022-11-25        51.0                      961
# 15427 2023-07-24        57.0                      761
# 15428 2023-07-05        60.0                      735
# 15429 2022-05-05        42.0                      341
# 15430 2021-10-07        68.0                      315
#
#                          occupation_category_description     NOC  \
# 0            FACILITY OPERATION AND MAINTENANCE MANAGERS   722.0
# 1                                MOTOR VEHICLE MECHANICS  7322.0
# 2                LONGSHORE WORKERS AND MATERIAL HANDLERS  7453.0
# 3      LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9613.0
# 4                      MOTOR VEHICLE AND TRANSIT DRIVERS  7412.0
# ...                                                  ...     ...
# 15426  LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9619.0
# 15427                       TRADES HELPERS AND LABOURERS  7612.0
# 15428  STATIONARY ENGINEERS & POWER STATION &  SYSTEM...  7353.0
# 15429  ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH SER...  3414.0
# 15430            NURSE SUPERVISORS AND REGISTERED NURSES  3153.0
#
#        worker_experience_in_years  \
# 0                             0.5
# 1                             0.5
# 2                             0.5
# 3                             0.5
# 4                             0.5
# ...                           ...
# 15426                         0.5
# 15427                         0.5
# 15428                         0.5
# 15429                         0.5
# 15430                         0.0
#
#                    accident_source_category_description1  \
# 0                                                 FLOORS
# 1                                                  TRUCK
# 2             PLANT & INDUSTRIAL POWERED VEHICLE, N.E.C.
# 3                                           PARKING LOTS
# 4                                       OTHER STRUCTURES
# ...                                                  ...
# 15426                                      STAIRS, STEPS
# 15427                                            TRACTOR
# 15428   BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15429  HEALTH CARE PATIENT OR RESIDENT OF HEALTH CARE...
# 15430                                             FLOORS
#
#                            source_category_description2  \
# 0                                               UNKNOWN
# 1                 VEHICLE & MOBILE EQUIP. PARTS, N.E.C.
# 2      BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 3                    WEATHER AND ATMOSPHERIC CONDITIONS
# 4                    WEATHER AND ATMOSPHERIC CONDITIONS
# ...                                                 ...
# 15426  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15427                                           UNKNOWN
# 15428  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 15429                                           UNKNOWN
# 15430           HEALTH CARE & ORTHOPEDIC EQUIP., N.E.C.
#
#                            accident_category_description  \
# 0                                     FALL ON SAME LEVEL
# 1              CAUGHT IN OR COMPRESSED BY EQUIP./OBJECTS
# 2                                       STRUCK BY OBJECT
# 3                                     FALL ON SAME LEVEL
# 4                                     FALL ON SAME LEVEL
# ...                                                  ...
# 15426                                FALL TO LOWER LEVEL
# 15427     PEDESTRIAN STRUCK BY VEHICLE, MOBILE EQUIPMENT
# 15428                                  REPETITIVE MOTION
# 15429  ASSAULTS, VIOLENT ACTS AND HARASSMENT BY PERSO...
# 15430                                 FALL ON SAME LEVEL
#
#                               accident_place_description        city  \
# 0                                    PLACE NOT SPECIFIED     markham
# 1                                                  FARM.    winnipeg
# 2      RESIDENTIAL INSTITUTION. (HOSPITALS, ORPHANAGE...   harriston
# 3                       PLACE FOR SPORTS AND RECREATION.     markham
# 4                                      PUBLIC BUILDINGS.   newcastle
# ...                                                  ...         ...
# 15426                                              HOME.     toronto
# 15427                                   INDUSTRIAL SITE.   dunchurch
# 15428                                   INDUSTRIAL SITE.        ajax
# 15429                                PLACE NOT SPECIFIED     toronto
# 15430                   PLACE FOR SPORTS AND RECREATION.  pittsburgh
#
#       organization_province_code  \
# 0                             ON
# 1                             MB
# 2                             ON
# 3                             ON
# 4                             ON
# ...                          ...
# 15426                         ON
# 15427                         ON
# 15428                         ON
# 15429                         ON
# 15430                         PA
#
#                                                   sector
# 0      other transportation equipment manufacturing W...
# 1             elementary and secondary schools Education
# 2       general warehousing and storage NEC - Industrial
# 3      all other miscellaneous fabricated metal produ...
# 4       general warehousing and storage NEC - Industrial
# ...                                                  ...
# 15426    hardware manufacturing Wood & Metal Fabrication
# 15427  commercial and institutional building construc...
# 15428  commercial and institutional building construc...
# 15429  iron and steel mills and ferro-alloy manufactu...
# 15430         home health care services Nursing Services
#
# [15431 rows x 13 columns]

# %% [markdown]
# ### Merging with events dataset

# %%
# events['sector'] = events['occupation_description'] + " " + events['sector_description']
# events = events.drop(columns=['occupation_description'])

# %%
temp = events.copy()
# temp['date'] = temp['date'].dt.strftime("%Y-%m")
temp['year'] = temp['date'].dt.year
temp['month'] = temp['date'].dt.month
accidents['year'] = accidents['date'].dt.year
accidents['month'] = accidents['date'].dt.month
temp = temp.drop(columns=['date'])
temp = temp.drop_duplicates()
merged = pd.merge(accidents, temp, on=['year', 'month', 'city', 'sector'], how='inner')
merged
# Out:
#            date  worker_age occupation_category_code  \
# 0    2023-11-23        45.0                      745
# 1    2023-06-26        30.0                      725
# 2    2023-11-24        46.0                      341
# 3    2023-11-24        46.0                      341
# 4    2023-11-27        58.0                      725
# ...         ...         ...                      ...
# 1100 2021-10-30        69.0                      666
# 1101 2021-11-02        60.0                      961
# 1102 2021-03-03        57.0                      315
# 1103 2021-07-19        46.0                      732
# 1104 2022-05-05        42.0                      341
#
#                         occupation_category_description     NOC  \
# 0               LONGSHORE WORKERS AND MATERIAL HANDLERS  7453.0
# 1                 PLUMBERS, PIPEFITTERS AND GAS FITTERS  7254.0
# 2     ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH IND...  3415.0
# 3     ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH IND...  3415.0
# 4                 PLUMBERS, PIPEFITTERS AND GAS FITTERS  7253.0
# ...                                                 ...     ...
# 1100                                           CLEANERS  6664.0
# 1101  LABOURERS IN PROCESSING, MANUFACTURING AND UTI...  9619.0
# 1102            NURSE SUPERVISORS AND REGISTERED NURSES  3153.0
# 1103                            MOTOR VEHICLE MECHANICS  7322.0
# 1104  ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH SER...  3414.0
#
#       worker_experience_in_years  \
# 0                            0.0
# 1                            0.5
# 2                            0.5
# 3                            0.5
# 4                            0.5
# ...                          ...
# 1100                         0.5
# 1101                        19.0
# 1102                        15.0
# 1103                         3.0
# 1104                         0.5
#
#                   accident_source_category_description1  \
# 0                METAL MATERIALS--NONSTRUCTURAL, N.E.C.
# 1                                  PIPES, DUCTS, TUBING
# 2                                                FLOORS
# 3                                                FLOORS
# 4                                              FORKLIFT
# ...                                                 ...
# 1100                                             FLOORS
# 1101                                      STAIRS, STEPS
# 1102                                             GROUND
# 1103                         STRUCTURAL METAL MATERIALS
# 1104  HEALTH CARE PATIENT OR RESIDENT OF HEALTH CARE...
#
#                           source_category_description2  \
# 0                                       SKIDS, PALLETS
# 1                PERSON--INJURED OR ILL WORKER, N.E.C.
# 2     BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 3     BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 4                           STRUCTURAL METAL MATERIALS
# ...                                                ...
# 1100                                           LIQUIDS
# 1101  BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 1102                WEATHER AND ATMOSPHERIC CONDITIONS
# 1103                                         FASTENERS
# 1104                                           UNKNOWN
#
#                           accident_category_description  \
# 0                                 STRUCK AGAINST OBJECT
# 1                                      STRUCK BY OBJECT
# 2                                    FALL ON SAME LEVEL
# 3                                    FALL ON SAME LEVEL
# 4             CAUGHT IN OR COMPRESSED BY EQUIP./OBJECTS
# ...                                                 ...
# 1100                                 FALL ON SAME LEVEL
# 1101                                FALL TO LOWER LEVEL
# 1102                                 FALL ON SAME LEVEL
# 1103                                   STRUCK BY OBJECT
# 1104  ASSAULTS, VIOLENT ACTS AND HARASSMENT BY PERSO...
#
#      accident_place_description  ...  \
# 0              INDUSTRIAL SITE.  ...
# 1              INDUSTRIAL SITE.  ...
# 2           PLACE NOT SPECIFIED  ...
# 3           PLACE NOT SPECIFIED  ...
# 4           PLACE NOT SPECIFIED  ...
# ...                         ...  ...
# 1100        STREET AND HIGHWAY.  ...
# 1101          PUBLIC BUILDINGS.  ...
# 1102                      HOME.  ...
# 1103          PUBLIC BUILDINGS.  ...
# 1104        PLACE NOT SPECIFIED  ...
#
#                                                  sector  year month  \
# 0            home health care services Nursing Services  2023    11
# 1     residential building construction Apartment & ...  2023     6
# 2            elementary and secondary schools Education  2023    11
# 3            elementary and secondary schools Education  2023    11
# 4            elementary and secondary schools Education  2023    11
# ...                                                 ...   ...   ...
# 1100         elementary and secondary schools Education  2021    10
# 1101         elementary and secondary schools Education  2021    11
# 1102     nursing care facilities Homes for Nursing Care  2021     3
# 1103         elementary and secondary schools Education  2021     7
# 1104  iron and steel mills and ferro-alloy manufactu...  2022     5
#
#                                    program         region     NAICS  \
# 0      Health Care Health & Safety Program   Central West  621610.0
# 1     Construction Health & Safety Program        Eastern  236110.0
# 2       Industrial Health & Safety Program   Central East  611110.0
# 3       Industrial Health & Safety Program   Central East  611110.0
# 4       Industrial Health & Safety Program   Central East  611110.0
# ...                                    ...            ...       ...
# 1100    Industrial Health & Safety Program   Central East  611110.0
# 1101    Industrial Health & Safety Program        Western  611110.0
# 1102   Health Care Health & Safety Program   Central West  623110.0
# 1103    Industrial Health & Safety Program  South Western  611110.0
# 1104    Industrial Health & Safety Program   Central East  331110.0
#
#                                  occupation_description  sector_code  \
# 0                             home health care services         NSER
# 1                     residential building construction         RESM
# 2                      elementary and secondary schools         EDUC
# 3                      elementary and secondary schools         EDUC
# 4                      elementary and secondary schools         EDUC
# ...                                                 ...          ...
# 1100                   elementary and secondary schools         EDUC
# 1101                   elementary and secondary schools         EDUC
# 1102                            nursing care facilities         HFNC
# 1103                   elementary and secondary schools         EDUC
# 1104  iron and steel mills and ferro-alloy manufactu...         STEL
#
#                       sector_description worker_count
# 0                       Nursing Services   50 or More
# 1     Apartment & Other Multiple Housing     20 to 49
# 2                              Education   50 or More
# 3                              Education     20 to 49
# 4                              Education   50 or More
# ...                                  ...          ...
# 1100                           Education     20 to 49
# 1101                           Education          NaN
# 1102              Homes for Nursing Care   50 or More
# 1103                           Education   50 or More
# 1104                      Primary Metals   50 or More
#
# [1105 rows x 22 columns]

# %% [markdown]
# #### Worker Count

# %%
import re
def text2num(item:str):
    res = re.findall("\d+", item)
    if len(res) == 1:
        return int(res[0])
    else:
        return (int(res[0]) + int(res[1]))//2

# %%
merged = merged.dropna(subset='worker_count')
merged['avg_worker_count'] = merged['worker_count'].apply(text2num)
merged
# Out:
# /var/folders/wn/wdlhry7x1m75kh1md7t0x5p00000gn/T/ipykernel_62595/673307198.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['avg_worker_count'] = merged['worker_count'].apply(text2num)
#            date  worker_age occupation_category_code  \
# 0    2023-11-23        45.0                      745
# 1    2023-06-26        30.0                      725
# 2    2023-11-24        46.0                      341
# 3    2023-11-24        46.0                      341
# 4    2023-11-27        58.0                      725
# ...         ...         ...                      ...
# 1098 2022-07-17        22.0                      667
# 1100 2021-10-30        69.0                      666
# 1102 2021-03-03        57.0                      315
# 1103 2021-07-19        46.0                      732
# 1104 2022-05-05        42.0                      341
#
#                         occupation_category_description     NOC  \
# 0               LONGSHORE WORKERS AND MATERIAL HANDLERS  7453.0
# 1                 PLUMBERS, PIPEFITTERS AND GAS FITTERS  7254.0
# 2     ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH IND...  3415.0
# 3     ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH IND...  3415.0
# 4                 PLUMBERS, PIPEFITTERS AND GAS FITTERS  7253.0
# ...                                                 ...     ...
# 1098  OTHER ATTENDANTS IN TRAVEL, ACCOMMODATION AND ...  6672.0
# 1100                                           CLEANERS  6664.0
# 1102            NURSE SUPERVISORS AND REGISTERED NURSES  3153.0
# 1103                            MOTOR VEHICLE MECHANICS  7322.0
# 1104  ASSISTING OCCUPATIONS IN SUPPORT OF HEALTH SER...  3414.0
#
#       worker_experience_in_years  \
# 0                            0.0
# 1                            0.5
# 2                            0.5
# 3                            0.5
# 4                            0.5
# ...                          ...
# 1098                         0.5
# 1100                         0.5
# 1102                        15.0
# 1103                         3.0
# 1104                         0.5
#
#                   accident_source_category_description1  \
# 0                METAL MATERIALS--NONSTRUCTURAL, N.E.C.
# 1                                  PIPES, DUCTS, TUBING
# 2                                                FLOORS
# 3                                                FLOORS
# 4                                              FORKLIFT
# ...                                                 ...
# 1098                                             GROUND
# 1100                                             FLOORS
# 1102                                             GROUND
# 1103                         STRUCTURAL METAL MATERIALS
# 1104  HEALTH CARE PATIENT OR RESIDENT OF HEALTH CARE...
#
#                           source_category_description2  \
# 0                                       SKIDS, PALLETS
# 1                PERSON--INJURED OR ILL WORKER, N.E.C.
# 2     BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 3     BODILY MOTION OR POSITION OF INJURED, ILL WORKER
# 4                           STRUCTURAL METAL MATERIALS
# ...                                                ...
# 1098                                           UNKNOWN
# 1100                                           LIQUIDS
# 1102                WEATHER AND ATMOSPHERIC CONDITIONS
# 1103                                         FASTENERS
# 1104                                           UNKNOWN
#
#                           accident_category_description  \
# 0                                 STRUCK AGAINST OBJECT
# 1                                      STRUCK BY OBJECT
# 2                                    FALL ON SAME LEVEL
# 3                                    FALL ON SAME LEVEL
# 4             CAUGHT IN OR COMPRESSED BY EQUIP./OBJECTS
# ...                                                 ...
# 1098                              STRUCK AGAINST OBJECT
# 1100                                 FALL ON SAME LEVEL
# 1102                                 FALL ON SAME LEVEL
# 1103                                   STRUCK BY OBJECT
# 1104  ASSAULTS, VIOLENT ACTS AND HARASSMENT BY PERSO...
#
#      accident_place_description  ...  year month  \
# 0              INDUSTRIAL SITE.  ...  2023    11
# 1              INDUSTRIAL SITE.  ...  2023     6
# 2           PLACE NOT SPECIFIED  ...  2023    11
# 3           PLACE NOT SPECIFIED  ...  2023    11
# 4           PLACE NOT SPECIFIED  ...  2023    11
# ...                         ...  ...   ...   ...
# 1098           INDUSTRIAL SITE.  ...  2022     7
# 1100        STREET AND HIGHWAY.  ...  2021    10
# 1102                      HOME.  ...  2021     3
# 1103          PUBLIC BUILDINGS.  ...  2021     7
# 1104        PLACE NOT SPECIFIED  ...  2022     5
#
#                                    program         region     NAICS  \
# 0      Health Care Health & Safety Program   Central West  621610.0
# 1     Construction Health & Safety Program        Eastern  236110.0
# 2       Industrial Health & Safety Program   Central East  611110.0
# 3       Industrial Health & Safety Program   Central East  611110.0
# 4       Industrial Health & Safety Program   Central East  611110.0
# ...                                    ...            ...       ...
# 1098  Construction Health & Safety Program   Central West  236220.0
# 1100    Industrial Health & Safety Program   Central East  611110.0
# 1102   Health Care Health & Safety Program   Central West  623110.0
# 1103    Industrial Health & Safety Program  South Western  611110.0
# 1104    Industrial Health & Safety Program   Central East  331110.0
#
#                                  occupation_description sector_code  \
# 0                             home health care services        NSER
# 1                     residential building construction        RESM
# 2                      elementary and secondary schools        EDUC
# 3                      elementary and secondary schools        EDUC
# 4                      elementary and secondary schools        EDUC
# ...                                                 ...         ...
# 1098  commercial and institutional building construc...        COMM
# 1100                   elementary and secondary schools        EDUC
# 1102                            nursing care facilities        HFNC
# 1103                   elementary and secondary schools        EDUC
# 1104  iron and steel mills and ferro-alloy manufactu...        STEL
#
#                       sector_description worker_count avg_worker_count
# 0                       Nursing Services   50 or More               50
# 1     Apartment & Other Multiple Housing     20 to 49               34
# 2                              Education   50 or More               50
# 3                              Education     20 to 49               34
# 4                              Education   50 or More               50
# ...                                  ...          ...              ...
# 1098    Commercial Building Construction   50 or More               50
# 1100                           Education     20 to 49               34
# 1102              Homes for Nursing Care   50 or More               50
# 1103                           Education   50 or More               50
# 1104                      Primary Metals   50 or More               50
#
# [1021 rows x 23 columns]

# %% [markdown]
# #### Saving

# %%
merged.to_csv("cleaned_data/merged.csv", index=0)

# %%
temp = merged.copy()
temp['date'] = temp['date'].dt.year
temp[['date', 'sector', 'worker_count', 'avg_worker_count']].drop_duplicates().head(20)
# Out:
#     date                                             sector worker_count  \
# 0   2023         home health care services Nursing Services   50 or More
# 1   2023  residential building construction Apartment & ...     20 to 49
# 2   2023         elementary and secondary schools Education   50 or More
# 3   2023         elementary and secondary schools Education     20 to 49
# 5   2023  iron and steel mills and ferro-alloy manufactu...   50 or More
# 6   2023  commercial and institutional building construc...      6 to 19
# 11  2022         elementary and secondary schools Education     20 to 49
# 12  2022         elementary and secondary schools Education       1 to 5
# 14  2022  residential building construction Apartment & ...   50 or More
# 15  2022         elementary and secondary schools Education   50 or More
# 16  2022  commercial and institutional building construc...   50 or More
# 20  2023  residential building construction Apartment & ...   50 or More
# 21  2023  commercial and institutional building construc...   50 or More
# 27  2022  commercial and institutional building construc...      6 to 19
# 46  2023     nursing care facilities Homes for Nursing Care   50 or More
# 53  2022  residential building construction Apartment & ...     20 to 49
# 55  2021  commercial and institutional building construc...   50 or More
# 59  2021  iron and steel mills and ferro-alloy manufactu...     20 to 49
# 60  2021  limited-service eating places Food, Beverage &...   50 or More
# 65  2022     nursing care facilities Homes for Nursing Care   50 or More
#
#     avg_worker_count
# 0                 50
# 1                 34
# 2                 50
# 3                 34
# 5                 50
# 6                 12
# 11                34
# 12                 3
# 14                50
# 15                50
# 16                50
# 20                50
# 21                50
# 27                12
# 46                50
# 53                34
# 55                50
# 59                34
# 60                50
# 65                50
